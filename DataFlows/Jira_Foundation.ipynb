# %%
# Library Import

import os 
import importlib.util

if importlib.util.find_spec("pandas") is None:	
	os.system("pip install pandas")

# %%
# pandas Config

import pandas as pd

pd.options.mode.use_inf_as_na = True
pd.set_option("display.max_rows", 10)
pd.set_option("display.expand_frame_repr", True)
pd.set_option('display.width', 1000)
pd.options.display.max_seq_items = 200000
pd.options.display.max_rows = 10

# %%
# Parameters

from ipython_secrets import get_secret

Host = get_secret('SECRETS_HOST') 
Username = get_secret('SECRETS_USERNAME') 
Password = get_secret('SECRETS_PASSWORD') 
ValidProjectCategories = ["'Customer Delivery Projects'"]

# %%
# Functions

import base64
import pandas as pd
import re 
import requests
from functools import reduce
    
def _ExpandColumn(self:pd.DataFrame, colName:str, columnsToExpand = [], prefix:str = "Prefix", sentenceCase:bool = True) -> pd.DataFrame:
    if (prefix == "Prefix"):
        prefix = colName + " "
        expandedCols = self[colName].apply(lambda x: pd.Series(x).add_prefix(prefix))
        columnsToExpand = [prefix + c for c in columnsToExpand]
    else:
        expandedCols = self[colName].apply(lambda x: pd.Series(x))
    
    if len(columnsToExpand) > 0:        
        expandedCols = expandedCols[columnsToExpand]
    
    if sentenceCase:
        expandedCols.columns = [fnSentenceCase(c) for c in expandedCols.columns] 

    return pd.concat([self.drop(colName, axis=1), expandedCols], axis=1)

pd.DataFrame.expand = _ExpandColumn

def fnSentenceCase(s):
    s = (' '.join(dict.fromkeys(s.split())))  # remove duplicate words
    s = s.replace("0", "") # remove "0" 
    s = s.strip()
    return ' '.join([x.capitalize() for x in re.sub(r"([A-Z])", r" \1", s).split()]) # sentence case

def _SentenceCaseColumns(self:pd.DataFrame) -> pd.DataFrame: 
    self.columns = [fnSentenceCase(c) for c in self.columns] 
    return self

pd.DataFrame.sentence_case_columns = _SentenceCaseColumns

def fnGetDefaultHeaders():
    return {
        "content-type": "application/json",
        "authorization": "Basic " + base64.b64encode((Username + ":" + Password).encode()).decode(),
        "retry-after": "120"
    }

def fnSearch(jql, fields = None, expand = None):
    def ApiCall(startAt) :
        url = "/rest/api/latest/search"
        headers = fnGetDefaultHeaders()
        defaultContents = {
            "startAt": startAt,
            "maxResults": "2",
            "jql": jql
        }
        if fields is not None:
            defaultContents["fields"] = fields.tolist()
        if expand is not None and expand != "":
            defaultContents["expand"] = expand        

        response = requests.post(Host + url, headers = headers, json = defaultContents)
        return response.json()
    values = fnAPI(ApiCall)
    if len(values.index) > 1:
        return values
    else:
        None

def fnGetIssueTypeFields(IssueTypes) -> pd.DataFrame:
    def ApiCall(startAt) :
        url = "rest/api/latest/issue/createmeta"
        headers = fnGetDefaultHeaders()
        params = {
            "expand": "projects.issuetypes.fields",
            "projectKeys": ','.join(fnGetValidProjectKeys()["key"].values),
            "issuetypeNames": ','.join(IssueTypes).replace("'", "")
        }
        response = requests.get(Host + url, headers = headers, params = params)
        return response.json()
    
    df = fnAPI(ApiCall)
    df = df.drop(["expand"], axis=1)
    df = df.explode("projects")
    df = df.expand("projects", [], None, False)
    df = df[["issuetypes"]]
    df = df.explode("issuetypes")
    df = df.expand("issuetypes", [], None, False)
    df = df[["fields"]]
    df = df.expand("fields", [], None, False)
    df = df.loc[:,~df.columns.duplicated()]

    values = []
    for x in df.columns:        
        try:            
            valid = pd.DataFrame( df[~df[x].isnull()] )[[x]].iloc[0].get(0)
            values.append({
                "fieldId": valid['key'],
                "name": valid['name'],
                "schema_type": valid['schema']['type'],
                "required": valid['required']
            })
        except:
            display(x)
            pass
    values.append({ "fieldId": 'status', "name": 'Status', "schema_type": 'string', "required": True })
    values.append({ "fieldId": 'created', "name": 'Created', "schema_type": 'date', "required": True })
    values.append({ "fieldId": 'updated', "name": 'Updated', "schema_type": 'date', "required": True })
    values.append({ "fieldId": 'resolution', "name": 'Resolution', "schema_type": 'string', "required": True })
    values.append({ "fieldId": 'resolutiondate', "name": 'Resolution Date', "schema_type": 'date', "required": False })
    values.append({ "fieldId": 'lastViewed', "name": 'Last Viewed', "schema_type": 'date', "required": True })
    values.append({ "fieldId": 'id', "name": 'Id', "schema_type": 'number', "required": True })
    values.append({ "fieldId": 'key', "name": 'Key', "schema_type": 'string', "required": True })
    df = pd.DataFrame(values)
    df = df.drop_duplicates().sort_values("fieldId")
    return df 

def fnGetValidProjectKeys() -> pd.DataFrame:
    def ApiCall(startAt) :
        url = "/rest/api/latest/project"
        headers = fnGetDefaultHeaders()
        params = { }
        response = requests.get(Host + url, headers = headers, params = params)
        return response.json()
    df = fnAPI(ApiCall)
    df = df.expand("projectCategory")
    if 'ValidProjectCategories' in globals() and len(ValidProjectCategories) > 0:
        df = df.loc[df['Project Category Name'].isin(ValidProjectCategories) | ("'" + df['Project Category Name'] + "'").isin(ValidProjectCategories)]
    return df[["key"]]

def fnAPI(webRequestDelegate, startAt = 0) -> pd.DataFrame:
    def flatten_reduce_lambda(frm):
        try:
            return list(reduce(lambda x, y: x + y, frm, []))         
        except:
            return list(reduce(lambda x, y: x + y, [frm], [])) 
    def innerGetResults(webRequestDelegate, startAt = 0):
        results = webRequestDelegate(startAt)
        if isinstance(results, dict) and "total" in results and "maxResults" in results:
            if startAt + results["maxResults"] < results["total"]:
                return [results] + innerGetResults(webRequestDelegate, startAt + results["maxResults"])
            else:
                return [results]
        else:
            return [results]
    Source = flatten_reduce_lambda(innerGetResults(webRequestDelegate, startAt))
    df = pd.DataFrame(Source)
    return df

# %%
# Projects

from IPython.display import display
import requests
from pandas.core.dtypes.dtypes import DatetimeTZDtype

def ApiCall(startAt) :
    url = "/rest/api/latest/project"
    headers = fnGetDefaultHeaders()
    params = {
        "startAt": startAt,
        "expand": "projectKeys"
    }
    response = requests.get(Host + url, headers = headers, params = params)
    return response.json()

df = fnAPI(ApiCall)  
df = df.drop(["avatarUrls", "expand", "self", "entityId", "uuid", "projectKeys", "properties"], axis=1).sentence_case_columns()
df = df.expand("Project Category", ["id", "name"])
df = df.expand("Archived By", ["accountId", "displayName"])
df["Is Valid"] = (
    df['Project Category Name'].isin(ValidProjectCategories) | ("'" + df['Project Category Name'] + "'").isin(ValidProjectCategories) if 'ValidProjectCategories' in globals() and len(ValidProjectCategories) > 0 else True
)

df = df.sentence_case_columns().convert_dtypes().infer_objects()
df["Id"] = df["Id"].astype('Int64')
df["Project Category Id"] = df["Project Category Id"].astype('Int64')
df["Archived Date"] = df["Archived Date"].astype(DatetimeTZDtype("ns", "+10:00"))

display(df.dtypes)
display(df)
# Out:
# Id                                   Int64
# Key                         string[python]
# Name                        string[python]
# Project Type Key            string[python]
# Simplified                         boolean
#                                  ...
# Project Category Id                  Int64
# Project Category Name       string[python]
# Archived By Account Id      string[python]
# Archived By Display Name    string[python]
# Is Valid                           boolean
# Length: 14, dtype: object
#        Id    Key                                               Name Project Type Key  Simplified    Style  Is Private  Archived                    Archived Date  Project Category Id                   Project Category Name    Archived By Account Id Archived By Display Name  Is Valid
# 0   13098  AHPRA                                             AHPRA      service_desk       False  classic        True      <NA>                              NaT                10106  Customer Delivery Projects (Atlassian)                      <NA>                     <NA>     False
# 1   13177    AAS                          AHPRA Application Support     service_desk       False  classic        True      <NA>                              NaT                10106  Customer Delivery Projects (Atlassian)                      <NA>                     <NA>     False
# 2   13091    AWS                                Amazon Web Services         business       False  classic       False      <NA>                              NaT                10102                       Internal Projects                      <NA>                     <NA>     False
# 3   13173   ANGT                                          Anglicare     service_desk       False  classic        True      <NA>                              NaT                10106  Customer Delivery Projects (Atlassian)                      <NA>                     <NA>     False
# 4   13101     PD                          Archived Project Delivery         software       False  classic       False      <NA>                              NaT                 <NA>                                    <NA>                      <NA>                     <NA>     False
# ..    ...    ...                                                ...              ...         ...      ...         ...       ...                              ...                  ...                                     ...                       ...                      ...       ...
# 77  13043     PP                    ZZ - PinPoint (Pest Monitoring)         software       False  classic       False      True 2022-07-27 16:09:13.865000+10:00                10104                     Product Development  62786daa0e2c490069023bf0             bibek behera     False
# 78  13005  SG738                   ZZ - QGCIO Cybersecurity (SG738)         software       False  classic       False      True 2022-07-27 16:09:27.771000+10:00                10101              Customer Delivery Projects  62786daa0e2c490069023bf0             bibek behera      True
# 79  13058  QTSIB  ZZ - Queensland Treasury - Strategic Informati...         software       False  classic       False      True 2022-07-27 16:09:33.217000+10:00                10101              Customer Delivery Projects  62786daa0e2c490069023bf0             bibek behera      True
# 80  13051     SE                            ZZ - Softlink Education         software       False  classic       False      True 2022-07-27 16:09:38.499000+10:00                10101              Customer Delivery Projects  62786daa0e2c490069023bf0             bibek behera      True
# 81  13037    SFM                        ZZ- Santos Fleet Management         software       False  classic       False      True 2022-07-27 16:09:46.265000+10:00                10101              Customer Delivery Projects  62786daa0e2c490069023bf0             bibek behera      True
#
# [82 rows x 14 columns]

# %%
# Project Keys

from IPython.display import display
import requests

def ApiCall(startAt) :
    url = "/rest/api/latest/project"
    headers = fnGetDefaultHeaders()
    params = {
        "startAt": startAt,
        "expand": "projectKeys"
    }
    response = requests.get(Host + url, headers = headers, params = params)
    return response.json()

df = fnAPI(ApiCall).sentence_case_columns()

df = df[["Id", "Key", "Project Keys"]]
df = df.explode("Project Keys")

df = df.sentence_case_columns().convert_dtypes().infer_objects()
df["Id"] = df["Id"].astype('Int64')

display(df.dtypes)
display(df)
# Out:
# Id                       Int64
# Key             string[python]
# Project Keys    string[python]
# dtype: object
#        Id    Key Project Keys
# 0   13098  AHPRA        AHPRA
# 1   13177    AAS          AAS
# 2   13091    AWS          AWS
# 3   13173   ANGT         ANGT
# 3   13173   ANGT           A1
# ..    ...    ...          ...
# 78  13005  SG738           QC
# 79  13058  QTSIB        QTSIB
# 80  13051     SE           SE
# 80  13051     SE         STIH
# 81  13037    SFM          SFM
#
# [110 rows x 3 columns]

# %%
# Project Properties

from IPython.display import display
import requests

def ApiCall(startAt) :
    url = "/rest/api/latest/project"
    headers = fnGetDefaultHeaders()
    params = {
        "startAt": startAt,
        "expand": "projectKeys"
    }
    response = requests.get(Host + url, headers = headers, params = params)
    return response.json()

df = fnAPI(ApiCall).sentence_case_columns()

df = df[["Id", "Key", "Properties"]]
df = df.explode("Properties")

df = df[~df["Properties"].isna()]
if df is None or len(df.index) == 0:	
    display("No results")
else:			
	df = df.sentence_case_columns().convert_dtypes().infer_objects()
	df["Id"] = df["Id"].astype('Int64')

	display(df.dtypes)
	display(df)
# Out:
# 'No results'

# %%
# Project Categories

from IPython.display import display
import requests

def ApiCall(startAt) :
    url = "/rest/api/latest/projectCategory"
    headers = fnGetDefaultHeaders()
    params = {
        "startAt": startAt
    }
    response = requests.get(Host + url, headers = headers, params = params)
    return response.json()

df = fnAPI(ApiCall)  
df = df.drop(["self"], axis=1)

df = df.sentence_case_columns().convert_dtypes().infer_objects()
df["Id"] = df["Id"].astype('Int64')

list_row = [0, "No Category", "No Category"]
df.loc[len(df)] = list_row
df = df.sort_values('Id')

display(df.dtypes)
display(df)
# Out:
# Id              Int64
# Description    object
# Name           object
# dtype: object
#       Id                                        Description                                    Name
# 9      0                                        No Category                             No Category
# 7  10000                                                                       Software Development
# 8  10100                                                                              Task Tracking
# 0  10101  A project set up to manage deliverables for a ...              Customer Delivery Projects
# 2  10102                     Internal Strategenics projects                       Internal Projects
# 6  10103  A project to support internal Strategenics Res...         Research & Development Projects
# 5  10104  A project for a product developed by Strategenics                     Product Development
# 4  10105              Projects for ongoing managed services                        Managed Services
# 1  10106               Atlassian Customer Delivery Projects  Customer Delivery Projects (Atlassian)
# 3  10107                                                              Internal Projects (Atlassian)

# %%
# Issue Types

from IPython.display import display
import requests

def ApiCall(startAt) :
    url = "/rest/api/latest/issuetype"
    headers = fnGetDefaultHeaders()
    params = {
        "startAt": startAt
    }
    response = requests.get(Host + url, headers = headers, params = params)
    return response.json()

df = fnAPI(ApiCall)  
df = df.drop(["self", "scope"], axis=1)
df = df.sentence_case_columns().convert_dtypes().infer_objects().reset_index(drop=True)
df["Id"] = df["Id"].astype('Int64')

df = df.sort_values('Name').reset_index(drop=True)

display(df.dtypes)
display(df)
# Out:
# Id                            Int64
# Description          string[python]
# Icon Url             string[python]
# Name                 string[python]
# Untranslated Name    string[python]
# Subtask                     boolean
# Avatar Id                     Int64
# Hierarchy Level               Int64
# dtype: object
#        Id                                        Description                                           Icon Url                                     Name                        Untranslated Name  Subtask  Avatar Id  Hierarchy Level
# 0   10104  For new system accounts or passwords. Created ...  https://strategenics.atlassian.net/servicedesk...                                   Access                                   Access    False       <NA>                0
# 1   10984                   Have a question? Submit it here.  https://strategenics.atlassian.net/rest/api/2/...                           Ask a question                           Ask a question    False      13390                0
# 2       1  A problem which impairs or prevents the functi...  https://strategenics.atlassian.net/rest/api/2/...                                      Bug                                      Bug    False      10303                0
# 3   10902                                                     https://strategenics.atlassian.net/rest/api/2/...                                     Bug*                                     Bug*     True      10303               -1
# 4   10102  For system upgrades or alterations. Created by...  https://strategenics.atlassian.net/servicedesk...                                   Change                                   Change    False       <NA>                0
# 5   10500                                                     https://strategenics.atlassian.net/rest/api/2/...                          Change - Gratis                          Change - Gratis    False      10309                0
# 6   10501                                                     https://strategenics.atlassian.net/rest/api/2/...                     Change - New Feature                     Change - New Feature    False      10314                0
# 7   10978  Send a request to make changes to your informa...  https://strategenics.atlassian.net/rest/api/2/...                           Change request                           Change request    False      13366                0
# 8   10905                                                     https://strategenics.atlassian.net/rest/api/2/...                                  Change*                                  Change*     True      11500               -1
# 9   10987  A recipient of a good, service, product or an ...  https://strategenics.atlassian.net/rest/api/2/...                                 Customer                                 Customer    False      13400                0
# 10  10912                                                     https://strategenics.atlassian.net/rest/api/2/...                                 Dev Task                                 Dev Task    False      10318                0
# 11  10402  This issue needs to be distributed into multip...  https://strategenics.atlassian.net/rest/api/2/...                                  Dissect                                  Dissect    False      10320                0
# 12  10982  Request received from your email support channel.  https://strategenics.atlassian.net/rest/api/2/...                          Emailed request                          Emailed request    False      13370                0
# 13  10981  Submit an offboarding request for an employee ...  https://strategenics.atlassian.net/rest/api/2/...                     Employee offboarding                     Employee offboarding    False      13369                0
# 14  10980       Submit an onboarding request for a new hire.  https://strategenics.atlassian.net/rest/api/2/...                      Employee onboarding                      Employee onboarding    False      13368                0
# 15  10000  A big user story that needs to be broken down....  https://strategenics.atlassian.net/rest/api/2/...                                     Epic                                     Epic    False      10307                1
# 16  11007                  Epics track large pieces of work.  https://strategenics.atlassian.net/rest/api/2/...                                     Epic                                     Epic    False      10307                1
# 17  10949                                                     https://strategenics.atlassian.net/rest/api/2/...                                    Event                                    Event    False      10300                0
# 18  10103  Track system outages or incidents. Created by ...  https://strategenics.atlassian.net/servicedesk...                                    Fault                                    Fault    False       <NA>                0
# 19  10999                                                     https://strategenics.atlassian.net/rest/api/2/...                                  Feature                                  Feature    False      10311                0
# 20  10401  Target functionality as implemented does not a...  https://strategenics.atlassian.net/rest/api/2/...                        Functional Defect                        Functional Defect    False      10308                0
# 21  10300                  A requirement that is functional.  https://strategenics.atlassian.net/rest/api/2/...                   Functional Requirement                   Functional Requirement    False      10300                0
# 22  10600               Strategenics internal quarterly goal  https://strategenics.atlassian.net/rest/api/2/...                                     Goal                                     Goal    False      12301                0
# 23  10100  For general IT problems and questions. Created...  https://strategenics.atlassian.net/servicedesk...                                  IT Help                                  IT Help    False       <NA>                0
# 24  10990                                     Discovery idea  https://strategenics.atlassian.net/rest/api/2/...                                     Idea                                     Idea    False      11501                0
# 25      4  An improvement or enhancement to an existing f...  https://strategenics.atlassian.net/rest/api/2/...                              Improvement                              Improvement    False      10310                0
# 26  10915  For system outages or incidents. Created by Ji...  https://strategenics.atlassian.net/rest/api/2/...                                 Incident                                 Incident    False      13282                0
# 27  10998                                                     https://strategenics.atlassian.net/rest/api/2/...                               Initiative                               Initiative    False      11501                0
# 28  10993                                                     https://strategenics.atlassian.net/rest/api/2/...                                  Invoice                                  Invoice    False      13434                0
# 29  11004          A realised risk that has become an issue.  https://strategenics.atlassian.net/rest/api/2/...                                    Issue                                    Issue    False      10304                0
# 30  10994                                                     https://strategenics.atlassian.net/rest/api/2/...                          Job Application                          Job Application    False      10311                0
# 31  10201             Issue type used for applying for leave  https://strategenics.atlassian.net/rest/api/2/...                        Leave Application                        Leave Application    False      10306                0
# 32  10933                                                     https://strategenics.atlassian.net/rest/api/2/...                                  Mention                                  Mention    False      10308                0
# 33      2  A new feature of the product, which has yet to...  https://strategenics.atlassian.net/rest/api/2/...                              New Feature                              New Feature    False      10311                0
# 34  10916  Track underlying causes of incidents. Created ...  https://strategenics.atlassian.net/rest/api/2/...                                  Problem                                  Problem    False      13283                0
# 35  10101  Track items that need to be bought. Created by...  https://strategenics.atlassian.net/servicedesk...                                 Purchase                                 Purchase    False       <NA>                0
# 36  10979      Send us a question or make a general request.  https://strategenics.atlassian.net/rest/api/2/...                         Questions for HR                         Questions for HR    False      13367                0
# 37  10903                                                     https://strategenics.atlassian.net/rest/api/2/...                                Reporting                                Reporting    False      10306                0
# 38  10988                                                     https://strategenics.atlassian.net/rest/api/2/...                                 Resource                                 Resource    False      13442                0
# 39  10985                                                     https://strategenics.atlassian.net/rest/api/2/...                                     Risk                                     Risk    False      10308                0
# 40  10913                      Created by Jira Service Desk.  https://strategenics.atlassian.net/rest/api/2/...                          Service Request                          Service Request    False      13280                0
# 41  10914  For requests that require approval. Created by...  https://strategenics.atlassian.net/rest/api/2/...           Service Request with Approvals           Service Request with Approvals    False      13281                0
# 42  10001  A user story. Created by JIRA Software - do no...  https://strategenics.atlassian.net/rest/api/2/...                                    Story                                    Story    False      10315                0
# 43  10989                                                     https://strategenics.atlassian.net/rest/api/2/...                          Sub-requirement                          Sub-requirement     True      10311               -1
# 44      5                          The sub-task of the issue  https://strategenics.atlassian.net/rest/api/2/...                                 Sub-task                                 Sub-task     True      10316               -1
# 45  10992  A small piece of work that's part of a larger ...  https://strategenics.atlassian.net/rest/api/2/...                                 Sub-task                                 Sub-task     True      10316               -1
# 46  11006  A small piece of work that's part of a larger ...  https://strategenics.atlassian.net/rest/api/2/...                                 Sub-task                                 Sub-task     True      10316               -1
# 47  10983              Submit a request or report a problem.  https://strategenics.atlassian.net/rest/api/2/...             Submit a request or incident             Submit a request or incident    False      13389                0
# 48  10800  For customer support issues. Created by JIRA S...  https://strategenics.atlassian.net/rest/api/2/...                                  Support                                  Support    False      13100                0
# 49  11005                   A small, distinct piece of work.  https://strategenics.atlassian.net/rest/api/2/...                                     Task                                     Task    False      10318                0
# 50      3                      A task that needs to be done.  https://strategenics.atlassian.net/rest/api/2/...                                     Task                                     Task    False      10318                0
# 51  10991                   A small, distinct piece of work.  https://strategenics.atlassian.net/rest/api/2/...                                     Task                                     Task    False      10318                0
# 52  10901                                                     https://strategenics.atlassian.net/rest/api/2/...                         Task (Untracked)                         Task (Untracked)    False      10318                0
# 53  10900  Any task which relates to repairing the damage...  https://strategenics.atlassian.net/rest/api/2/...                           Technical Debt                           Technical Debt    False      10300                0
# 54  10400  Technical implementation of the target functio...  https://strategenics.atlassian.net/rest/api/2/...                         Technical Defect                         Technical Defect    False      10304                0
# 55  10002  Created by JIRA Agile - do not edit or delete....  https://strategenics.atlassian.net/images/icon...                           Technical task                           Technical task     True       <NA>               -1
# 56  10700  This JIRA Issue Type is used to create Zephyr ...  https://strategenics.atlassian.net/rest/api/2/...                                     Test                                     Test    False      12600                0
# 57  10986                 Used for time tracking in projects  https://strategenics.atlassian.net/rest/api/2/...                            Time tracking                            Time tracking    False      13397                0
# 58  10951                                                     https://strategenics.atlassian.net/rest/api/2/...                              WFH - Adhoc                              WFH - Adhoc    False      10300                0
# 59  10950                                                     https://strategenics.atlassian.net/rest/api/2/...                          WFH - Recurring                          WFH - Recurring    False      10300                0
# 60  10976                Created by Jira Service Management.  https://strategenics.atlassian.net/rest/api/2/...                          [System] Change                          [System] Change    False      13352                0
# 61  10973  For system outages or incidents. Created by Ji...  https://strategenics.atlassian.net/rest/api/2/...                        [System] Incident                        [System] Incident    False      13349                0
# 62  10977  Track underlying causes of incidents. Created ...  https://strategenics.atlassian.net/rest/api/2/...                         [System] Problem                         [System] Problem    False      13353                0
# 63  10974             A request that follows ITSM workflows.  https://strategenics.atlassian.net/rest/api/2/...                 [System] Service request                 [System] Service request    False      13350                0
# 64  10975             A request that follows ITSM workflows.  https://strategenics.atlassian.net/rest/api/2/...  [System] Service request with approvals  [System] Service request with approvals    False      13351                0

# %%
# Project Types

from IPython.display import display
import requests

def ApiCall(startAt) :
    url = "/rest/api/latest/project/type"
    headers = fnGetDefaultHeaders()
    params = {}
    response = requests.get(Host + url, headers = headers, params = params)
    return response.json()

df = fnAPI(ApiCall)  
df = df.sentence_case_columns().convert_dtypes().infer_objects().reset_index(drop=True)
df = df.sort_values('Key').reset_index(drop=True)

display(df.dtypes)
display(df)
# Out:
# Key                     string[python]
# Formatted Key           string[python]
# Description I18n Key    string[python]
# Icon                    string[python]
# Color                   string[python]
# dtype: object
#                  Key      Formatted Key  \
# 3           business           Business
# 0  product_discovery  Product Discovery
# 2       service_desk       Service Desk
# 1           software           Software
#
#                             Description I18n Key  \
# 3         jira.project.type.business.description
# 0          jira.project.type.polaris.description
# 2  jira.project.type.servicedesk.description.jsm
# 1         jira.project.type.software.description
#
#                                                 Icon    Color
# 3  PD94bWwgdmVyc2lvbj0iMS4wIiBlbmNvZGluZz0iaXNvLT...  #1D8832
# 0  PD94bWwgdmVyc2lvbj0iMS4wIiBlbmNvZGluZz0iaXNvLT...  #F5A623
# 2  PD94bWwgdmVyc2lvbj0iMS4wIiBlbmNvZGluZz0iaXNvLT...  #67AB49
# 1  PD94bWwgdmVyc2lvbj0iMS4wIiBlbmNvZGluZz0iaXNvLT...  #F5A623

# %%
# Resolutions

from IPython.display import display
import requests

def ApiCall(startAt) :
    url = "/rest/api/latest/resolution"
    headers = fnGetDefaultHeaders()
    params = {}
    response = requests.get(Host + url, headers = headers, params = params)
    return response.json()

df = fnAPI(ApiCall)  
df = df.drop(["self"], axis=1)
df = df.sentence_case_columns().convert_dtypes().infer_objects().reset_index(drop=True)
df["Id"] = df["Id"].astype('Int64')
df = df.sort_values('Name').reset_index(drop=True)

display(df.dtypes)
display(df)
# Out:
# Id                      Int64
# Description    string[python]
# Name           string[python]
# dtype: object
#        Id                                        Description              Name
# 2   10301                                                            Cancelled
# 7   10302                                                           Cannot Fix
# 5       5  All attempts at reproducing this issue failed,...  Cannot Reproduce
# 11  10200                       This issue was not approved.          Declined
# 0   10000                                                                 Done
# 3       3   The problem is a duplicate of an existing issue.         Duplicate
# 1       1  A fix for this issue is checked into the tree ...             Fixed
# 12  10303                                                     Hardware failure
# 4       4           The problem is not completely described.        Incomplete
# 6   10201  The problem has a documented root cause and a ...       Known Error
# 13  10304                                                     Software failure
# 10  10100                      This issue won't be actioned.          Won't Do
# 8       2  The problem described is an issue which will n...         Won't Fix
# 9   10300  The problem will not be fixed at this point in...     Won't Fix Now

# %%
# Status

from IPython.display import display
import requests

def ApiCall(startAt) :
    url = "/rest/api/latest/status"
    headers = fnGetDefaultHeaders()
    params = {}
    response = requests.get(Host + url, headers = headers, params = params)
    return response.json()

df = fnAPI(ApiCall)  
df = df.drop(["self", "scope"], axis=1)
df = df.expand("statusCategory", ["id", "name"])

df = df.sentence_case_columns().convert_dtypes().infer_objects().reset_index(drop=True)
df["Id"] = df["Id"].astype('Int64')
df = df.sort_values('Name').reset_index(drop=True)

display(df.dtypes)
display(df)
# Out:
# Description             string[python]
# Icon Url                string[python]
# Name                    string[python]
# Untranslated Name       string[python]
# Id                               Int64
# Status Category Id               Int64
# Status Category Name    string[python]
# dtype: object
#                                           Description                                           Icon Url                            Name               Untranslated Name     Id  Status Category Id Status Category Name
# 0                                                      https://strategenics.atlassian.net/images/icon...                        Assigned                        Assigned  11955                   2                To Do
# 1   This was auto-generated by Jira Service Manage...  https://strategenics.atlassian.net/images/icon...                       Authorize                       Authorize  11929                   4          In Progress
# 2   This was auto-generated by Jira Service Desk d...  https://strategenics.atlassian.net/images/icon...         Awaiting implementation         Awaiting implementation  11847                   4          In Progress
# 3                                                      https://strategenics.atlassian.net/images/icon...                         Backlog                         Backlog  10400                   2                To Do
# 4                                                      https://strategenics.atlassian.net/images/icon...                        Beta/UAT                        Beta/UAT  11810                   4          In Progress
# 5   This issue can't proceed due to a change in re...  https://strategenics.atlassian.net/images/icon...               Blocked by Change               Blocked by Change      4                   2                To Do
# 6   Source code has been committed, and JIRA is wa...  https://strategenics.atlassian.net/images/icon...                        Building                        Building    400                   4          In Progress
# 7   This status is managed internally by JIRA Soft...                https://strategenics.atlassian.net/    Built, Further Data Required    Built, Further Data Required  11308                   4          In Progress
# 8   This status is managed internally by JIRA Soft...                https://strategenics.atlassian.net/         Built, Ready For Review         Built, Ready For Review  11306                   4          In Progress
# 9   This status is managed internally by JIRA Soft...                https://strategenics.atlassian.net/         Built, Ready To Publish         Built, Ready To Publish  11309                   4          In Progress
# 10  This status is managed internally by JIRA Soft...                https://strategenics.atlassian.net/             Built, Under Review             Built, Under Review  11307                   4          In Progress
# 11  This was auto-generated by JIRA Service Desk d...  https://strategenics.atlassian.net/images/icon...                        Canceled                        Canceled  11702                   3                 Done
# 12         Application or approval has been cancelled  https://strategenics.atlassian.net/images/icon...                       Cancelled                       Cancelled  10303                   3                 Done
# 13                                                                   https://strategenics.atlassian.net/                      Clear need                      Clear need  11947                   2                To Do
# 14  This status is managed internally by Jira Soft...                https://strategenics.atlassian.net/                   Client Review                   Client Review  11808                   4          In Progress
# 15  The issue is considered finished, the resoluti...  https://strategenics.atlassian.net/images/icon...                          Closed                          Closed      6                   3                 Done
# 16                                                     https://strategenics.atlassian.net/images/icon...                     Closed Lost                     Closed Lost  11940                   3                 Done
# 17  This status is managed internally by JIRA Soft...                https://strategenics.atlassian.net/                    Collect Data                    Collect Data  11303                   4          In Progress
# 18                                                     https://strategenics.atlassian.net/images/icon...         Commercial Finalisation         Commercial Finalisation  11939                   2                To Do
# 19  This was auto-generated by Jira Service Desk d...  https://strategenics.atlassian.net/images/icon...                       Completed                       Completed  11916                   3                 Done
# 20  This status is managed internally by JIRA Soft...                https://strategenics.atlassian.net/                    Consultation                    Consultation  11301                   4          In Progress
# 21  This was auto-generated by JIRA Service Desk d...  https://strategenics.atlassian.net/images/icon...                        Declined                        Declined  11700                   3                 Done
# 22                                                                   https://strategenics.atlassian.net/                          Define                          Define  11949                   4          In Progress
# 23                                                     https://strategenics.atlassian.net/images/icon...                 Deployed to Dev                 Deployed to Dev  11809                   4          In Progress
# 24                                                     https://strategenics.atlassian.net/images/icon...                          Design                          Design  11886                   2                To Do
# 25                                                     https://strategenics.atlassian.net/images/icon...                    Dev Complete                    Dev Complete  11400                   4          In Progress
# 26                                                     https://strategenics.atlassian.net/images/icon...               Dev Test Complete               Dev Test Complete  11402                   4          In Progress
# 27                                                     https://strategenics.atlassian.net/images/icon...            Dev Test In Progress            Dev Test In Progress  11401                   4          In Progress
# 28                                                     https://strategenics.atlassian.net/images/icon...                            Done                            Done  11806                   3                 Done
# 29                                                                   https://strategenics.atlassian.net/                            Done                            Done  11941                   3                 Done
# 30                                                                   https://strategenics.atlassian.net/                       Empathise                       Empathise  11948                   4          In Progress
# 31  This was auto-generated by JIRA Service Desk d...  https://strategenics.atlassian.net/images/icon...                       Escalated                       Escalated  11703                   4          In Progress
# 32  This status is managed internally by JIRA Soft...                https://strategenics.atlassian.net/           Evaluate Data Quality           Evaluate Data Quality  11304                   4          In Progress
# 33  This was auto-generated by Jira Service Manage...  https://strategenics.atlassian.net/images/icon...                          Failed                          Failed  11930                   3                 Done
# 34                                                                   https://strategenics.atlassian.net/                          Ideate                          Ideate  11950                   4          In Progress
# 35  This status is managed internally by JIRA Soft...                https://strategenics.atlassian.net/                   Identify Data                   Identify Data  11302                   4          In Progress
# 36  This was auto-generated by Jira Service Desk d...  https://strategenics.atlassian.net/images/icon...                    Implementing                    Implementing  11848                   4          In Progress
# 37                                                     https://strategenics.atlassian.net/images/icon...                     In Delivery                     In Delivery  11938                   4          In Progress
# 38  This issue is being actively worked on at the ...  https://strategenics.atlassian.net/images/icon...                  In Development                  In Development      3                   4          In Progress
# 39  This issue is being actively worked on at the ...  https://strategenics.atlassian.net/images/icon...                     In Progress                     In Progress  10600                   4          In Progress
# 40                                                                   https://strategenics.atlassian.net/                       In Review                       In Review  10900                   4          In Progress
# 41  This status is managed internally by Jira Soft...                https://strategenics.atlassian.net/                 Internal Review                 Internal Review  11807                   4          In Progress
# 42                                                     https://strategenics.atlassian.net/images/icon...                            Lead                            Lead  11935                   2                To Do
# 43                                                                   https://strategenics.atlassian.net/                     Learn/Build                     Learn/Build  11946                   4          In Progress
# 44                                                     https://strategenics.atlassian.net/images/icon...                             New                             New  11954                   2                To Do
# 45  The issue is open and ready for the assignee t...  https://strategenics.atlassian.net/images/icon...                            Open                            Open      1                   2                To Do
# 46                                                                   https://strategenics.atlassian.net/                     Parking lot                     Parking lot  11943                   2                To Do
# 47                                                     https://strategenics.atlassian.net/images/icon...                     Peer Review                     Peer Review  11811                   4          In Progress
# 48  This was auto-generated by JIRA Service Desk d...  https://strategenics.atlassian.net/images/icon...                         Pending                         Pending  11701                   2                To Do
# 49                                                     https://strategenics.atlassian.net/images/icon...    Pending Response to Customer    Pending Response to Customer  11840                   4          In Progress
# 50  This was auto-generated by Jira Service Desk d...  https://strategenics.atlassian.net/images/icon...                        Planning                        Planning  11846                   2                To Do
# 51                                                     https://strategenics.atlassian.net/images/icon...                Progress Blocked                Progress Blocked  11812                   4          In Progress
# 52                                                     https://strategenics.atlassian.net/images/icon...                   Proposal sent                   Proposal sent  11936                   2                To Do
# 53                                                                   https://strategenics.atlassian.net/                       Prototype                       Prototype  11951                   4          In Progress
# 54  This status is managed internally by JIRA Soft...                https://strategenics.atlassian.net/                      Published!                      Published!  11310                   4          In Progress
# 55                                                     https://strategenics.atlassian.net/images/icon...                       Qualified                       Qualified  11937                   2                To Do
# 56  This status is managed internally by JIRA Soft...                https://strategenics.atlassian.net/  Ready For Build (or Rebuild Po  Ready For Build (or Rebuild Po  11305                   4          In Progress
# 57                                                     https://strategenics.atlassian.net/images/icon...           Ready for Development           Ready for Development  11102                   2                To Do
# 58                                                     https://strategenics.atlassian.net/images/icon...               Ready for Release               Ready for Release  11404                   3                 Done
# 59                                                     https://strategenics.atlassian.net/images/icon...                Ready for Review                Ready for Review  10101                   2                To Do
# 60  This status is managed internally by Jira Soft...                https://strategenics.atlassian.net/               Ready for Testing               Ready for Testing  11915                   4          In Progress
# 61                                                     https://strategenics.atlassian.net/images/icon...                   Ready for UAT                   Ready for UAT  10502                   2                To Do
# 62                                                     https://strategenics.atlassian.net/images/icon...                  Ready to Start                  Ready to Start  11814                   2                To Do
# 63                                                     https://strategenics.atlassian.net/images/icon...                        Released                        Released  10100                   3                 Done
# 64  This was auto-generated by JIRA Service Desk d...  https://strategenics.atlassian.net/images/icon...                        Reopened                        Reopened  11705                   1          No Category
# 65  This status is managed internally by Jira Soft...                https://strategenics.atlassian.net/           Requirements Approved           Requirements Approved  11914                   4          In Progress
# 66  A resolution has been taken, and it is awaitin...  https://strategenics.atlassian.net/images/icon...                        Resolved                        Resolved      5                   3                 Done
# 67  This status is managed internally by JIRA Soft...                https://strategenics.atlassian.net/                          Review                          Review  11000                   4          In Progress
# 68                                                     https://strategenics.atlassian.net/images/icon...                 Review Complete                 Review Complete  11101                   2                To Do
# 69                                                     https://strategenics.atlassian.net/images/icon...              Review In Progress              Review In Progress  10501                   2                To Do
# 70                                                     https://strategenics.atlassian.net/images/icon...                 Review/Approval                 Review/Approval  11815                   2                To Do
# 71                                                                   https://strategenics.atlassian.net/        Selected for Development        Selected for Development  11834                   2                To Do
# 72                                                     https://strategenics.atlassian.net/images/icon...                     Spec Review                     Spec Review  10401                   2                To Do
# 73                                                                   https://strategenics.atlassian.net/                            Test                            Test  11952                   4          In Progress
# 74                                                     https://strategenics.atlassian.net/images/icon...                     Test Failed                     Test Failed  11405                   4          In Progress
# 75                                                     https://strategenics.atlassian.net/images/icon...                           To Do                           To Do  10102                   2                To Do
# 76                                                     https://strategenics.atlassian.net/images/icon...                 UAT In Progress                 UAT In Progress  11403                   4          In Progress
# 77                                                     https://strategenics.atlassian.net/images/icon...                    Under Review                    Under Review  11200                   4          In Progress
# 78  This was auto-generated by Jira Service Desk d...  https://strategenics.atlassian.net/images/icon...             Under investigation             Under investigation  11851                   4          In Progress
# 79  This status is managed internally by Jira Soft...                https://strategenics.atlassian.net/                         Waiting                         Waiting  11839                   2                To Do
# 80  This issue is waiting on a response or solutio...  https://strategenics.atlassian.net/images/icon...           Waiting for 3rd Party           Waiting for 3rd Party  10200                   2                To Do
# 81                                                     https://strategenics.atlassian.net/images/icon...             Waiting for Bug Fix             Waiting for Bug Fix  11829                   2                To Do
# 82  This was auto-generated by JIRA Service Desk d...  https://strategenics.atlassian.net/images/icon...            Waiting for Customer            Waiting for Customer  10001                   2                To Do
# 83  This was auto-generated by JIRA Service Desk d...  https://strategenics.atlassian.net/images/icon...             Waiting for Support             Waiting for Support  10000                   4          In Progress
# 84  This was auto-generated by Jira Service Desk d...  https://strategenics.atlassian.net/images/icon...            Waiting for approval            Waiting for approval  11844                   2                To Do
# 85  This was auto-generated by JIRA Service Desk d...  https://strategenics.atlassian.net/images/icon...                Work in progress                Work in progress  11704                   4          In Progress

# %%
# Status Categories

from IPython.display import display
import requests

def ApiCall(startAt) :
    url = "/rest/api/latest/statuscategory"
    headers = fnGetDefaultHeaders()
    params = {}
    response = requests.get(Host + url, headers = headers, params = params)
    return response.json()

df = fnAPI(ApiCall)  
df = df.drop(["self"], axis=1)

df = df.sentence_case_columns().convert_dtypes().infer_objects().reset_index(drop=True)
df["Id"] = df["Id"].astype('Int64')
df = df.sort_values('Id').reset_index(drop=True)

display(df.dtypes)
display(df)
# Out:
# Id                     Int64
# Key           string[python]
# Color Name    string[python]
# Name          string[python]
# dtype: object
#    Id            Key   Color Name         Name
# 0   1      undefined  medium-gray  No Category
# 1   2            new    blue-gray        To Do
# 2   3           done        green         Done
# 3   4  indeterminate       yellow  In Progress

# %%
# Users

from IPython.display import display
import requests
import pandas as pd

def ApiCall(startAt) :
    url = "/rest/api/latest/users/search"
    headers = fnGetDefaultHeaders()
    params = {
        "startAt": startAt,
        "maxResults": "1000"
    }
    response = requests.get(Host + url, headers = headers, params = params)
    return response.json()

df = pd.concat([fnAPI(ApiCall, x * 1000) for x in range(0, 10)])
df = df.drop(["self"], axis=1)

df = df.expand("avatarUrls", ["48x48"]).rename(columns={"Avatar Urls 48x48": "Avatar Url"})

df = df.sentence_case_columns().convert_dtypes().infer_objects().reset_index(drop=True)
df = df.sort_values('Display Name').reset_index(drop=True)

display(df.dtypes)
display(df)
# Out:
# Account Id       string[python]
# Account Type     string[python]
# Email Address    string[python]
# Display Name     string[python]
# Active                  boolean
# Time Zone        string[python]
# Locale           string[python]
# Avatar Url       string[python]
# dtype: object
#                                             Account Id Account Type                    Email Address                              Display Name  Active Time Zone Locale                                         Avatar Url
# 391  qm:0956ac3a-a022-4a10-a3c5-22e5fd6f75cf:5c80c3...     customer                             <NA>                         2014490606@qq.com    True      <NA>   <NA>  https://avatar-management--avatars.us-west-2.p...
# 919                           6139d99124ba8b00701a07b1    atlassian  aws-support@strategenics.com.au           AWS-SUPPORT@strategenics.com.au    True      <NA>   <NA>  https://secure.gravatar.com/avatar/6fd0cc8a51c...
# 65                            632113a7cd4a82cf977cafdb    atlassian                             <NA>                               Adrian Hill    True      <NA>  en_GB  https://secure.gravatar.com/avatar/939dc6b1cfe...
# 442        557057:fa71e034-c716-4a38-96eb-e3d8f5e106ca    atlassian                             <NA>                                     Adven   False      <NA>  en_US  https://avatar-management--avatars.us-west-2.p...
# 932                           5e5c7ada5a495e0c91a9a2a1    atlassian                             <NA>                            Agnieszka Klyz    True      <NA>  en_GB  https://secure.gravatar.com/avatar/a12986dd346...
# ..                                                 ...          ...                              ...                                       ...     ...       ...    ...                                                ...
# 111  qm:0956ac3a-a022-4a10-a3c5-22e5fd6f75cf:3e9f95...     customer                             <NA>               wmalovnek@interactit.com.au    True      <NA>   <NA>  https://avatar-management--avatars.us-west-2.p...
# 266  qm:0956ac3a-a022-4a10-a3c5-22e5fd6f75cf:5c32c0...     customer                             <NA>         yamiko.kambalametore@intertek.com    True      <NA>   <NA>  https://avatar-management--avatars.us-west-2.p...
# 27   qm:0956ac3a-a022-4a10-a3c5-22e5fd6f75cf:8c9ec0...     customer                             <NA>                 yasmineazzaoui2@gmail.com    True      <NA>   <NA>  https://avatar-management--avatars.us-west-2.p...
# 540  qm:0956ac3a-a022-4a10-a3c5-22e5fd6f75cf:101b82...     customer                             <NA>                        yourmail@gmail.com    True      <NA>   <NA>  https://avatar-management--avatars.us-west-2.p...
# 16                            64105b5ab05b4e3e7da87d05    atlassian                             <NA>  zz_ConnectorSetup@p334.teams.maxo.com.au    True      <NA>   <NA>  https://secure.gravatar.com/avatar/c35453cd320...
#
# [1115 rows x 8 columns]

# %%
# Priorities

from IPython.display import display
import requests

def ApiCall(startAt) :
    url = "/rest/api/latest/priority"
    headers = fnGetDefaultHeaders()
    params = {}
    response = requests.get(Host + url, headers = headers, params = params)
    return response.json()

df = fnAPI(ApiCall)  
df = df.drop(["self"], axis=1)

df = df.sentence_case_columns().convert_dtypes().infer_objects().reset_index(drop=True)
df["Id"] = df["Id"].astype('Int64')
df = df.sort_values('Id').reset_index(drop=True)

display(df.dtypes)
display(df)
# Out:
# Status Color    string[python]
# Description     string[python]
# Icon Url        string[python]
# Name            string[python]
# Id                       Int64
# dtype: object
#   Status Color Description                                           Icon Url         Name  Id
# 0      #cc0000       to do  https://strategenics.atlassian.net/images/icon...     Critical   1
# 1      #ff0000       to do  https://strategenics.atlassian.net/images/icon...         High   2
# 2      #009900       to do  https://strategenics.atlassian.net/images/icon...       Medium   3
# 3      #006600       to do  https://strategenics.atlassian.net/images/icon...          Low   4
# 4      #003300       to do  https://strategenics.atlassian.net/images/icon...  Enhancement   5
